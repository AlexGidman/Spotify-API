# %% [markdown]
# ## SpotifyAPI Client
# This notebook contains a fully documented copy of the SpotifyAPI Class.

# %%
import requests
import base64
import datetime
from urllib.parse import urlencode

# %%
class SpotifyAPI(object):
    """A class to make authorised api requests to Spotify.
    
    Can perform authentication to obtain an access token for the spotify api, and then make requests of that api
    such as searching for artist, album, or track data.
    
      Typical usage example:
      
      spotify = SpotifyAPI(client_id, client_secret)
      results = spotify.search(query={"track": "money", "artist": "pink floyd"}, 
                              search_type="track", 
                              market_type="US")
    
    Attributes:
        access_token: a time-limited access token string provided by spotify for making api requests.
        access_token_expires: time at which current access_token expires.
        access_token_did_expire: expresses whether access_token has expired or not.
        client_id: spotify client id for the application.
        client_secret: spotify client secret for the application, relates to specific client id.
        token_url: url for obtaining spotify access token .
    """
    
    access_token = None
    access_token_expires = datetime.datetime.now
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"

    
    def __init__(self, client_id: str, client_secret: str, *args, **kwargs) -> None:
        """Inits SpotifyAPI class and performs authentication.
        
        Args:
            client_id (str): spotify client id for the application.
            client_secret (str): spotify client secret for the application, relates to specific client id.
        """
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        self.perform_auth()
       
    
    def get_client_credentials(self) -> str:
        """Combines client_id and client_secret to create a single base64 encoded string.
        
        Returns:
            client_creds_b64.decode(): client-id and client_secret combined as a base64 encoded string.
        """
        
        client_id = self.client_id
        client_secret = self.client_secret
        
        if client_secret == None or client_id == None:
            raise Exception("client_id and client_secret required.")
            
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    
    def get_token_headers(self) -> dict:
        """Creates headers for access token api request.
        
        Returns:
            A dict containing a formatted string for access token requests contining client credential information.
        """
        
        client_creds_b64 = self.get_client_credentials()
        return { 
        "Authorization" : f"Basic {client_creds_b64}"
        }
    
    
    def get_token_data(self) -> dict:
        """Creates token data as a dict.
                
        Returns:
            A dict containing access token request data, authorisation granted based on client credential information.
        """
        
        return {"grant_type" : "client_credentials"}
    
    
    def get_access_token(self) -> str:
        """Obtains and returns a valid access token.
        
        Returns:
            token(str): access token for making authenticated api requests to Spotify.
        """
        
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
     
        
    def perform_auth(self) -> bool:
        """Performs authentication for making api requests to Spotify.
        
        Returns:
            True once authentication has been successfully completed.
            
        Raises:
            Exception: Authentication failed - ensure client credentials are correct.
        """
        
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            raise Exception("Authentication failed - ensure client credentials are correct.")
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    

    def get_resource_headers(self) -> dict:
        """Creates headers for resource api request.
        
        Returns:
            headers(dict): a dict containing access token for making  authorised api requests.
        """
        
        access_token = self.get_access_token()
        headers = {"Authorization": f"Bearer {access_token}"}
        return headers
    
    
    def get_resource(self, lookup_id: str, resource_type: str="track", version: str="v1") -> dict:
        """Makes an api request for resources from spotify.
        
        Retrieves JSON data related to resource request type and returns as a dict of 
        unaltered data.
        
        Args:
            lookup_id(str): a string of 22 alphanumeric characters related to a specific object 
              such as artist, track, album etc.
            resource_type(str): type of resource that relates to lookup_id such as 'track', 'artist', 
              'album' etc.
            version(str): a string relating to version of spotify api. At point of creation only v1 is 
              available.
        
        Returns:
            r.json() (dict): a dict containing unaltered data related to the requested resource. If 
              request is unsuccessful, returns an empty dict.  
        """
        
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_headers()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    
    def get_artist(self, lookup_id: str) -> dict:
        """Gets artist data from spotify based on lookup_id
        
        Args:
            lookup_id(str): a string of 22 alphanumeric characters related to specific artist, 
              usually obtained from SpotifyAPI.search().
        
        Returns:
            A dict containing raw unaltered data related to the artist. If request is 
              unsuccessful, returns an empty dict.
        """
        
        return self.get_resource(lookup_id, resource_type="artists")
    
    
    def get_album(self, lookup_id: str) -> dict:
        """Gets album data from spotify based on lookup_id
        
        Args:
            lookup_id(str): a string of 22 alphanumeric characters related to specific album, 
              usually obtained from SpotifyAPI.search().
        
        Returns:
            A dict containing raw unaltered data related to the album. If request is 
              unsuccessful, returns an empty dict.
        """
        
        return self.get_resource(lookup_id, resource_type="albums")
    
    
    def get_track(self, lookup_id: str) -> dict:
        """Gets track data from spotify based on lookup_id
        
        Args:
            lookup_id(str): a string of 22 alphanumeric characters related to specific track, 
              usually obtained from SpotifyAPI.search().
        
        Returns:
            A dict containing raw unaltered data related to the track. If request is 
              unsuccessful, returns an empty dict.
        """
        
        return self.get_resource(lookup_id, resource_type="tracks")
    
    
    def get_track_features(self, lookup_id: str) -> dict:
        """Gets album data from spotify based on lookup_id
        
        Args:
            lookup_id(str): a string of 22 alphanumeric characters related to specific album, 
              usually obtained from SpotifyAPI.search().
        
        Returns:
            A dict containing raw unaltered data related to the album. If request is 
              unsuccessful, returns an empty dict.
        """
        
        return self.get_resource(lookup_id, resource_type="audio-features")

    
    def search(self, query: dict=None, search_type: str="artist", market_type: str="GB") -> dict:
        """Makes an api request for search data from spotify.
        
        Retrieves JSON data related to search request and returns as a dict of 
        unaltered data.
        
        Args:
            query(dict): the search query as a dict of parameters such as {'track': '<song_title>'}
            search_type(str): the type of search to be conducted such as for a 'track', 'artists', 
              'albums' etc.
            market_type(str): a string relating to market the searchable object is available in;
              "GB", "US" etc.

        Returns:
            r.json() (dict): a dict containing unaltered data related to the search request. If 
              request is unsuccessful, returns an empty dict.  
        """
        
        if query == None:
            raise Exception("A query is required")
        
        query_string=""
        for key,value in query.items():
            query_string += f"{key}:{value} "

        query_params = urlencode({"q" : query_string, "type" : search_type.lower(), "market" : market_type})
        lookup_url = f"https://api.spotify.com/v1/search?{query_params}"
        headers = self.get_resource_headers()
        
        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        if not r.status_code in range(200, 299):
            return {}
        return r.json()
   
    
    def get_tracks(self, query: dict=None) -> list:
        """Gets tracks from an api search request
        
        Retrieves JSON data related to search request and returns as a formatted list of dicts for
        easy lookup and manipulation. 
          
          Typical usage Example:
          
          results = SpotifyAPI.get_tracks({'track': 'money'})
          first_result = results[0]
          print(first_result)
          >>> {'track_id': _,
               'track_name: _,
               'artist': _,
               'track_url': _,
               'image_url': _}
        
        Args:
            query(dict): the search query as a dict of parameters such as {'track': '<song_title>'}

        Returns:
            tracks (list): a list of dicts containing formatted track data. See example above.
        """
        
        json_data = self.search(query, "track")
        try: 
            tracks = [{'track_id': i['id'], 
              'track_name': i['name'],
              'artist': i['artists'][0]['name'],
              'track_url': i['external_urls']['spotify'],
              'image_url': i['album']['images'][0]['url']
             } for i in json_data['tracks']['items']]
        except:
            printf("json_data dict not valid")
            return [] 
        return tracks
    
    
    def get_musical_data(self, track_id: str) -> dict:
        """Gets key and tempo info related to track
        
          Typical usage example:
          
          results = SpotifyAPI.get_musical_data("XXXXyyyyYYYYxxxxZZZZab")
          print(results)
          >>> {'track_id': XXXXyyyyYYYYxxxxZZZZab,
               'key': 'B Minor',
               'tempo': 120}
        
        Args:
            lookup_id(str): a string of 22 alphanumeric characters related to specific track, 
              usually obtained from SpotifyAPI.search().

        Returns:
            musical_data(dict): a dict containing formatted key & tempo information.
            
        Raises:
            Exception: No data found - check track_id
        """
        
        try:
            track_data = self.get_track_features(track_id)
            key = self.key_convert(track_data['key'], track_data['mode'])
            tempo = int(track_data['tempo'])
            musical_data = {"track_id": track_id,
                            "key": key,
                            "tempo": tempo}
            return musical_data
        except:
            raise Exception("No data found - check track_id")
        
    
    def key_convert(self, key: int, mode: int=None) -> str:
        """Converts key and mode value to musical key format (eg "B Minor")
        
        Args:
            key(int): a value that corresponds to one of 12 musical keys.
            mode(int): a value that indicates if major or minor key
        
        Returns:
            A formatted string that represents the musical key eg 'Gb', 'A Major', 'D Minor'. 
            If no valid key present, returns "No Key Available"
        """
       
        if key < 0 or key > 11:
            return "No Key Available"
        
        keys = {0: "C", 1: "Db", 2: "D", 3: "Eb",
                4: "E", 5: "F", 6: "Gb", 7: "G",
                8: "Ab", 9: "A", 10: "Bb", 11: "B"}
        
        if mode == 1:
            return f"{keys[key]} Major"
        elif mode == 0:
            return f"{keys[key]} Minor"  
        else:
            return keys[key]

# %% [markdown]
# ### SEARCH
# Let's try searching for something!

# %%
client_id = "a3aadf7f4d184af0af9d849d96e89b12"
client_secret = "6aa5d17510694af9a68e1deadb5e0a8f"

# %%
# Create spotify Api instance
spotify = SpotifyAPI(client_id, client_secret)
# Search for tracks using multiple query arguements.
spotify.search(query={"track": "back in black"}, search_type="track")
# Out:
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3Aback+in+black+&type=track&market=GB&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#        'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#        'id': '711MCceyCBcFnzjGY4Q7Un',
#        'name': 'AC/DC',
#        'type': 'artist',
#        'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6mUdeDZCsExyJLMdAfDuwh'},
#      'href': 'https://api.spotify.com/v1/albums/6mUdeDZCsExyJLMdAfDuwh',
#      'id': '6mUdeDZCsExyJLMdAfDuwh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730b51f8d91f3a21e8426361ae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020b51f8d91f3a21e8426361ae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510b51f8d91f3a21e8426361ae',
#        'width': 64}],
#      'name': 'Back In Black',
#      'release_date': '1980-07-25',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6mUdeDZCsExyJLMdAfDuwh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#       'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#       'id': '711MCceyCBcFnzjGY4Q7Un',
#       'name': 'AC/DC',
#       'type': 'artist',
#       'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#     'disc_number': 1,
#     'duration_ms': 255493,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUAP08000046'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/08mG3Y1vljYA6bvDt4Wqkj'},
#     'href': 'https://api.spotify.com/v1/tracks/08mG3Y1vljYA6bvDt4Wqkj',
#     'id': '08mG3Y1vljYA6bvDt4Wqkj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black',
#     'popularity': 84,
#     'preview_url': 'https://p.scdn.co/mp3-preview/506bc9a0485990973449b0467791e06174371284?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:08mG3Y1vljYA6bvDt4Wqkj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#        'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#        'id': '6urzdpGY5yUimWZsgJUoTb',
#        'name': 'Airbourne',
#        'type': 'artist',
#        'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ulIP4JbW6KegM8KNC02k5'},
#      'href': 'https://api.spotify.com/v1/albums/4ulIP4JbW6KegM8KNC02k5',
#      'id': '4ulIP4JbW6KegM8KNC02k5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733b99007a3d0b4a5d326843a4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023b99007a3d0b4a5d326843a4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513b99007a3d0b4a5d326843a4',
#        'width': 64}],
#      'name': 'Black Dog Barking (Special Edition)',
#      'release_date': '2013-05-17',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4ulIP4JbW6KegM8KNC02k5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'disc_number': 1,
#     'duration_ms': 205506,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA321392615'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5S5GRSDNdEPjNjj07gORMf'},
#     'href': 'https://api.spotify.com/v1/tracks/5S5GRSDNdEPjNjj07gORMf',
#     'id': '5S5GRSDNdEPjNjj07gORMf',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In The Game',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/acae6ca9265acfe87525c510955b43397aa935ee?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5S5GRSDNdEPjNjj07gORMf'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#        'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#        'id': '711MCceyCBcFnzjGY4Q7Un',
#        'name': 'AC/DC',
#        'type': 'artist',
#        'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4ydl8Ci7OsndhI2ALnrpIv'},
#      'href': 'https://api.spotify.com/v1/albums/4ydl8Ci7OsndhI2ALnrpIv',
#      'id': '4ydl8Ci7OsndhI2ALnrpIv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b56115c0e231fbf69d3205c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b56115c0e231fbf69d3205c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b56115c0e231fbf69d3205c6',
#        'width': 64}],
#      'name': 'Iron Man 2',
#      'release_date': '2010-04-29',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:4ydl8Ci7OsndhI2ALnrpIv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#       'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#       'id': '711MCceyCBcFnzjGY4Q7Un',
#       'name': 'AC/DC',
#       'type': 'artist',
#       'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#     'disc_number': 1,
#     'duration_ms': 255640,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUAP08000046'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2iEGj7kAwH7HAa5epwYwLB'},
#     'href': 'https://api.spotify.com/v1/tracks/2iEGj7kAwH7HAa5epwYwLB',
#     'id': '2iEGj7kAwH7HAa5epwYwLB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a51d64d5bfa4749043c0205eb5511ca590dc9052?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2iEGj7kAwH7HAa5epwYwLB'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#        'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#        'id': '0TnOYISbd1XYRBk9myaseg',
#        'name': 'Pitbull',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/79sREUp5MwQ8dwCaus3joa'},
#      'href': 'https://api.spotify.com/v1/albums/79sREUp5MwQ8dwCaus3joa',
#      'id': '79sREUp5MwQ8dwCaus3joa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d879716aef8b4c681ddd0290',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d879716aef8b4c681ddd0290',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d879716aef8b4c681ddd0290',
#        'width': 64}],
#      'name': 'Back in Time (featured in "Men In Black 3")',
#      'release_date': '2012-03-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:79sREUp5MwQ8dwCaus3joa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#       'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#       'id': '0TnOYISbd1XYRBk9myaseg',
#       'name': 'Pitbull',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#     'disc_number': 1,
#     'duration_ms': 205680,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11200227'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2U2ONBrf1HJCDxQlynpD6J'},
#     'href': 'https://api.spotify.com/v1/tracks/2U2ONBrf1HJCDxQlynpD6J',
#     'id': '2U2ONBrf1HJCDxQlynpD6J',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Time - featured in "Men In Black 3"',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/23f32a0c4979033c7963b31e35c1c4f4be6b2351?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2U2ONBrf1HJCDxQlynpD6J'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#        'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#        'id': '711MCceyCBcFnzjGY4Q7Un',
#        'name': 'AC/DC',
#        'type': 'artist',
#        'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4H6JMsvxmh0U7VBYiWiyLa'},
#      'href': 'https://api.spotify.com/v1/albums/4H6JMsvxmh0U7VBYiWiyLa',
#      'id': '4H6JMsvxmh0U7VBYiWiyLa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730a80b890ab011362fd7aa73b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020a80b890ab011362fd7aa73b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510a80b890ab011362fd7aa73b',
#        'width': 64}],
#      'name': 'Live at River Plate',
#      'release_date': '2012-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:4H6JMsvxmh0U7VBYiWiyLa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#       'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#       'id': '711MCceyCBcFnzjGY4Q7Un',
#       'name': 'AC/DC',
#       'type': 'artist',
#       'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#     'disc_number': 1,
#     'duration_ms': 255053,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11205793'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7JLqofLzcpdjFHc6oRSBGf'},
#     'href': 'https://api.spotify.com/v1/tracks/7JLqofLzcpdjFHc6oRSBGf',
#     'id': '7JLqofLzcpdjFHc6oRSBGf',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black - Live at River Plate Stadium, Buenos Aires, Argentina - December 2009',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/985e6265b2d913666e27604a42eb65726bd8b8b5?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7JLqofLzcpdjFHc6oRSBGf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#        'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#        'id': '711MCceyCBcFnzjGY4Q7Un',
#        'name': 'AC/DC',
#        'type': 'artist',
#        'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1dmBXO2zmCbsf8qAicqbs0'},
#      'href': 'https://api.spotify.com/v1/albums/1dmBXO2zmCbsf8qAicqbs0',
#      'id': '1dmBXO2zmCbsf8qAicqbs0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c5a5b4be2acc36cddc42fb8f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c5a5b4be2acc36cddc42fb8f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c5a5b4be2acc36cddc42fb8f',
#        'width': 64}],
#      'name': 'Live',
#      'release_date': '1992-10-27',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1dmBXO2zmCbsf8qAicqbs0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#       'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#       'id': '711MCceyCBcFnzjGY4Q7Un',
#       'name': 'AC/DC',
#       'type': 'artist',
#       'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#     'disc_number': 1,
#     'duration_ms': 266533,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUAP09200023'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5dvfYJR8yXaO9SHtqJWeL5'},
#     'href': 'https://api.spotify.com/v1/tracks/5dvfYJR8yXaO9SHtqJWeL5',
#     'id': '5dvfYJR8yXaO9SHtqJWeL5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black - Live - 1991',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eae17afbd6f7db07a4cb6041e65efd5b7eb6849b?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5dvfYJR8yXaO9SHtqJWeL5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#        'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#        'id': '0TnOYISbd1XYRBk9myaseg',
#        'name': 'Pitbull',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7vARFzgdVkbrHWheIKMkZk'},
#      'href': 'https://api.spotify.com/v1/albums/7vARFzgdVkbrHWheIKMkZk',
#      'id': '7vARFzgdVkbrHWheIKMkZk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27365045141bb6f165542741ded',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0265045141bb6f165542741ded',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485165045141bb6f165542741ded',
#        'width': 64}],
#      'name': 'Global Warming: Meltdown',
#      'release_date': '2012',
#      'release_date_precision': 'year',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7vARFzgdVkbrHWheIKMkZk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#       'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#       'id': '0TnOYISbd1XYRBk9myaseg',
#       'name': 'Pitbull',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#     'disc_number': 1,
#     'duration_ms': 207760,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11200227'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0xh2kZQ3rDB47IS8aVNqrf'},
#     'href': 'https://api.spotify.com/v1/tracks/0xh2kZQ3rDB47IS8aVNqrf',
#     'id': '0xh2kZQ3rDB47IS8aVNqrf',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Time - featured in "Men In Black 3"',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f8074e5506727ae145dd10ec62938fff40a13af4?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0xh2kZQ3rDB47IS8aVNqrf'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#        'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#        'id': '0TnOYISbd1XYRBk9myaseg',
#        'name': 'Pitbull',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4aawyAB9vmqN3uQ7FjRGTy'},
#      'href': 'https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy',
#      'id': '4aawyAB9vmqN3uQ7FjRGTy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c5b24ecfa39523a75c993c4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c5b24ecfa39523a75c993c4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c5b24ecfa39523a75c993c4',
#        'width': 64}],
#      'name': 'Global Warming',
#      'release_date': '2012-11-16',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:4aawyAB9vmqN3uQ7FjRGTy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#       'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#       'id': '0TnOYISbd1XYRBk9myaseg',
#       'name': 'Pitbull',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#     'disc_number': 1,
#     'duration_ms': 207440,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11200227'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7fmpKF0rLGPnP7kcQ5ZMm7'},
#     'href': 'https://api.spotify.com/v1/tracks/7fmpKF0rLGPnP7kcQ5ZMm7',
#     'id': '7fmpKF0rLGPnP7kcQ5ZMm7',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Time - featured in "Men In Black 3"',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1830a237c8d882990d633bddb336b83effac2237?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7fmpKF0rLGPnP7kcQ5ZMm7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#        'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#        'id': '711MCceyCBcFnzjGY4Q7Un',
#        'name': 'AC/DC',
#        'type': 'artist',
#        'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6jOO0YHvuHP4UkJuDpcAoz'},
#      'href': 'https://api.spotify.com/v1/albums/6jOO0YHvuHP4UkJuDpcAoz',
#      'id': '6jOO0YHvuHP4UkJuDpcAoz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27326b32820b869763b5d706c26',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0226b32820b869763b5d706c26',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485126b32820b869763b5d706c26',
#        'width': 64}],
#      'name': "Live (Collector's Edition)",
#      'release_date': '1992-10-27',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:6jOO0YHvuHP4UkJuDpcAoz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/711MCceyCBcFnzjGY4Q7Un'},
#       'href': 'https://api.spotify.com/v1/artists/711MCceyCBcFnzjGY4Q7Un',
#       'id': '711MCceyCBcFnzjGY4Q7Un',
#       'name': 'AC/DC',
#       'type': 'artist',
#       'uri': 'spotify:artist:711MCceyCBcFnzjGY4Q7Un'}],
#     'disc_number': 1,
#     'duration_ms': 267373,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUAP09200023'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1MfedNodDKkvTVkNkwIBSo'},
#     'href': 'https://api.spotify.com/v1/tracks/1MfedNodDKkvTVkNkwIBSo',
#     'id': '1MfedNodDKkvTVkNkwIBSo',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black - Live - 1991',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1618d038a7f8b673de8e2584550df199a7a91eb5?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1MfedNodDKkvTVkNkwIBSo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1PK9RsfL7i81kMZ4c9wcbR'},
#        'href': 'https://api.spotify.com/v1/artists/1PK9RsfL7i81kMZ4c9wcbR',
#        'id': '1PK9RsfL7i81kMZ4c9wcbR',
#        'name': 'The Neon Crew',
#        'type': 'artist',
#        'uri': 'spotify:artist:1PK9RsfL7i81kMZ4c9wcbR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/30ap20PdUMk1Iut1YBjMjm'},
#      'href': 'https://api.spotify.com/v1/albums/30ap20PdUMk1Iut1YBjMjm',
#      'id': '30ap20PdUMk1Iut1YBjMjm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a21619da608f8e276108a8f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a21619da608f8e276108a8f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a21619da608f8e276108a8f9',
#        'width': 64}],
#      'name': 'Comic-Con Heroes',
#      'release_date': '2014-04-04',
#      'release_date_precision': 'day',
#      'total_tracks': 45,
#      'type': 'album',
#      'uri': 'spotify:album:30ap20PdUMk1Iut1YBjMjm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1PK9RsfL7i81kMZ4c9wcbR'},
#       'href': 'https://api.spotify.com/v1/artists/1PK9RsfL7i81kMZ4c9wcbR',
#       'id': '1PK9RsfL7i81kMZ4c9wcbR',
#       'name': 'The Neon Crew',
#       'type': 'artist',
#       'uri': 'spotify:artist:1PK9RsfL7i81kMZ4c9wcbR'}],
#     'disc_number': 1,
#     'duration_ms': 254000,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAM461001177'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6JzkxKjghgLsj14OGz7uKZ'},
#     'href': 'https://api.spotify.com/v1/tracks/6JzkxKjghgLsj14OGz7uKZ',
#     'id': '6JzkxKjghgLsj14OGz7uKZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Black (From "Iron Man 2")',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/22feed158b05c5ee2f519f5097ff2b24e79d9328?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:6JzkxKjghgLsj14OGz7uKZ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19RHMn8FFkEFmhPwyDW2ZC'},
#        'href': 'https://api.spotify.com/v1/artists/19RHMn8FFkEFmhPwyDW2ZC',
#        'id': '19RHMn8FFkEFmhPwyDW2ZC',
#        'name': 'Robyn Adele Anderson',
#        'type': 'artist',
#        'uri': 'spotify:artist:19RHMn8FFkEFmhPwyDW2ZC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3mqpSsl44q9CHb1gasGaq7'},
#      'href': 'https://api.spotify.com/v1/albums/3mqpSsl44q9CHb1gasGaq7',
#      'id': '3mqpSsl44q9CHb1gasGaq7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d252f84b8b61eaffd44e23c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d252f84b8b61eaffd44e23c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d252f84b8b61eaffd44e23c1',
#        'width': 64}],
#      'name': 'Back in Black',
#      'release_date': '2020-10-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3mqpSsl44q9CHb1gasGaq7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19RHMn8FFkEFmhPwyDW2ZC'},
#       'href': 'https://api.spotify.com/v1/artists/19RHMn8FFkEFmhPwyDW2ZC',
#       'id': '19RHMn8FFkEFmhPwyDW2ZC',
#       'name': 'Robyn Adele Anderson',
#       'type': 'artist',
#       'uri': 'spotify:artist:19RHMn8FFkEFmhPwyDW2ZC'}],
#     'disc_number': 1,
#     'duration_ms': 171021,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZMEP2035119'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4mB7rPwxaQu7WvEHGGulg8'},
#     'href': 'https://api.spotify.com/v1/tracks/4mB7rPwxaQu7WvEHGGulg8',
#     'id': '4mB7rPwxaQu7WvEHGGulg8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Black',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/51738024fa0825870c4e094c582b48e04fc84b7f?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4mB7rPwxaQu7WvEHGGulg8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Fi8CHfO8WGtu3yO8c2Mc4'},
#        'href': 'https://api.spotify.com/v1/artists/6Fi8CHfO8WGtu3yO8c2Mc4',
#        'id': '6Fi8CHfO8WGtu3yO8c2Mc4',
#        'name': '2CELLOS',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5A7KUpEHEJvQJwZCjh5qgV'},
#      'href': 'https://api.spotify.com/v1/albums/5A7KUpEHEJvQJwZCjh5qgV',
#      'id': '5A7KUpEHEJvQJwZCjh5qgV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27320ef0f3cdc133b54f9279839',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0220ef0f3cdc133b54f9279839',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485120ef0f3cdc133b54f9279839',
#        'width': 64}],
#      'name': 'Back In Black (Live)',
#      'release_date': '2013-05-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5A7KUpEHEJvQJwZCjh5qgV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Fi8CHfO8WGtu3yO8c2Mc4'},
#       'href': 'https://api.spotify.com/v1/artists/6Fi8CHfO8WGtu3yO8c2Mc4',
#       'id': '6Fi8CHfO8WGtu3yO8c2Mc4',
#       'name': '2CELLOS',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Fi8CHfO8WGtu3yO8c2Mc4'}],
#     'disc_number': 1,
#     'duration_ms': 251746,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11302646'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6z2IGbRAxckusZeMstZ0vH'},
#     'href': 'https://api.spotify.com/v1/tracks/6z2IGbRAxckusZeMstZ0vH',
#     'id': '6z2IGbRAxckusZeMstZ0vH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black (Live)',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7aabe8d052eb1197576d50e7697a5bc87cbe5db1?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6z2IGbRAxckusZeMstZ0vH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0B7Y5KDNScTBzeN7DY74YG'},
#        'href': 'https://api.spotify.com/v1/artists/0B7Y5KDNScTBzeN7DY74YG',
#        'id': '0B7Y5KDNScTBzeN7DY74YG',
#        'name': 'Tryhardninja',
#        'type': 'artist',
#        'uri': 'spotify:artist:0B7Y5KDNScTBzeN7DY74YG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4TQ0wWEL3SNrKHj6ihlgYE'},
#      'href': 'https://api.spotify.com/v1/albums/4TQ0wWEL3SNrKHj6ihlgYE',
#      'id': '4TQ0wWEL3SNrKHj6ihlgYE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737aacddc3faa2a680c5d80b58',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027aacddc3faa2a680c5d80b58',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517aacddc3faa2a680c5d80b58',
#        'width': 64}],
#      'name': 'Video Game Songs, Vol. 1',
#      'release_date': '2016-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 37,
#      'type': 'album',
#      'uri': 'spotify:album:4TQ0wWEL3SNrKHj6ihlgYE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0B7Y5KDNScTBzeN7DY74YG'},
#       'href': 'https://api.spotify.com/v1/artists/0B7Y5KDNScTBzeN7DY74YG',
#       'id': '0B7Y5KDNScTBzeN7DY74YG',
#       'name': 'Tryhardninja',
#       'type': 'artist',
#       'uri': 'spotify:artist:0B7Y5KDNScTBzeN7DY74YG'}],
#     'disc_number': 1,
#     'duration_ms': 189353,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM7MR1500706'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06VeVP9K5PIGOwsXV9VBbV'},
#     'href': 'https://api.spotify.com/v1/tracks/06VeVP9K5PIGOwsXV9VBbV',
#     'id': '06VeVP9K5PIGOwsXV9VBbV',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Black',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e947fa80d734688b24ad8af267a02a9afc0ee459?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:06VeVP9K5PIGOwsXV9VBbV'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3PszI7zvrBGFt14Hpg692F'},
#        'href': 'https://api.spotify.com/v1/artists/3PszI7zvrBGFt14Hpg692F',
#        'id': '3PszI7zvrBGFt14Hpg692F',
#        'name': 'Channel Aid',
#        'type': 'artist',
#        'uri': 'spotify:artist:3PszI7zvrBGFt14Hpg692F'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2yTmZ1PwFKkO0FjQp2flPl'},
#        'href': 'https://api.spotify.com/v1/artists/2yTmZ1PwFKkO0FjQp2flPl',
#        'id': '2yTmZ1PwFKkO0FjQp2flPl',
#        'name': 'Allie Sherlock',
#        'type': 'artist',
#        'uri': 'spotify:artist:2yTmZ1PwFKkO0FjQp2flPl'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7KddiJwkfiBBqC7mFnaf2X'},
#      'href': 'https://api.spotify.com/v1/albums/7KddiJwkfiBBqC7mFnaf2X',
#      'id': '7KddiJwkfiBBqC7mFnaf2X',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ed288b0c9efcc0c9455a898d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ed288b0c9efcc0c9455a898d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ed288b0c9efcc0c9455a898d',
#        'width': 64}],
#      'name': 'Channel Aid live in Concert 2020 - Live from Elbphilharmonie',
#      'release_date': '2020-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:7KddiJwkfiBBqC7mFnaf2X'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3PszI7zvrBGFt14Hpg692F'},
#       'href': 'https://api.spotify.com/v1/artists/3PszI7zvrBGFt14Hpg692F',
#       'id': '3PszI7zvrBGFt14Hpg692F',
#       'name': 'Channel Aid',
#       'type': 'artist',
#       'uri': 'spotify:artist:3PszI7zvrBGFt14Hpg692F'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2yTmZ1PwFKkO0FjQp2flPl'},
#       'href': 'https://api.spotify.com/v1/artists/2yTmZ1PwFKkO0FjQp2flPl',
#       'id': '2yTmZ1PwFKkO0FjQp2flPl',
#       'name': 'Allie Sherlock',
#       'type': 'artist',
#       'uri': 'spotify:artist:2yTmZ1PwFKkO0FjQp2flPl'}],
#     'disc_number': 1,
#     'duration_ms': 189855,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA372000569'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1uAwbHHaDSKJyn90618TB7'},
#     'href': 'https://api.spotify.com/v1/tracks/1uAwbHHaDSKJyn90618TB7',
#     'id': '1uAwbHHaDSKJyn90618TB7',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back To Black - Channel Aid live in Concert 2020 - Live from Elbphilharmonie',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/40dae1dea3a4d0b72e66c6af3a2e83a24628238b?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1uAwbHHaDSKJyn90618TB7'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CEZrAeabrLAbYzGTvw52e'},
#        'href': 'https://api.spotify.com/v1/artists/3CEZrAeabrLAbYzGTvw52e',
#        'id': '3CEZrAeabrLAbYzGTvw52e',
#        'name': 'Sershen&Zaritskaya',
#        'type': 'artist',
#        'uri': 'spotify:artist:3CEZrAeabrLAbYzGTvw52e'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2wxRdGlLxkh52LAce9JKUr'},
#      'href': 'https://api.spotify.com/v1/albums/2wxRdGlLxkh52LAce9JKUr',
#      'id': '2wxRdGlLxkh52LAce9JKUr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732755d6e4e725a4dc53f7ba5f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022755d6e4e725a4dc53f7ba5f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512755d6e4e725a4dc53f7ba5f',
#        'width': 64}],
#      'name': 'Back in Black',
#      'release_date': '2019-11-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2wxRdGlLxkh52LAce9JKUr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3CEZrAeabrLAbYzGTvw52e'},
#       'href': 'https://api.spotify.com/v1/artists/3CEZrAeabrLAbYzGTvw52e',
#       'id': '3CEZrAeabrLAbYzGTvw52e',
#       'name': 'Sershen&Zaritskaya',
#       'type': 'artist',
#       'uri': 'spotify:artist:3CEZrAeabrLAbYzGTvw52e'}],
#     'disc_number': 1,
#     'duration_ms': 315959,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHNB1975622'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6gS95ZPBPe5W04ATRlJNuI'},
#     'href': 'https://api.spotify.com/v1/tracks/6gS95ZPBPe5W04ATRlJNuI',
#     'id': '6gS95ZPBPe5W04ATRlJNuI',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Black',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a0087248a4a28690b35da48f1723fb44d4a50ffd?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6gS95ZPBPe5W04ATRlJNuI'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L56gAwU2WofuHHOpLC0BU'},
#        'href': 'https://api.spotify.com/v1/artists/5L56gAwU2WofuHHOpLC0BU',
#        'id': '5L56gAwU2WofuHHOpLC0BU',
#        'name': 'Tiger Stripes',
#        'type': 'artist',
#        'uri': 'spotify:artist:5L56gAwU2WofuHHOpLC0BU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ssWNFFObqiCevBeMWeYkz'},
#      'href': 'https://api.spotify.com/v1/albums/0ssWNFFObqiCevBeMWeYkz',
#      'id': '0ssWNFFObqiCevBeMWeYkz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c9cb8604700381eb8f88543',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c9cb8604700381eb8f88543',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c9cb8604700381eb8f88543',
#        'width': 64}],
#      'name': 'Back in Black',
#      'release_date': '2020-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:0ssWNFFObqiCevBeMWeYkz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L56gAwU2WofuHHOpLC0BU'},
#       'href': 'https://api.spotify.com/v1/artists/5L56gAwU2WofuHHOpLC0BU',
#       'id': '5L56gAwU2WofuHHOpLC0BU',
#       'name': 'Tiger Stripes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5L56gAwU2WofuHHOpLC0BU'}],
#     'disc_number': 1,
#     'duration_ms': 457134,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUR62000090'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vVg3dn0xdcPSNOGw9zZzB'},
#     'href': 'https://api.spotify.com/v1/tracks/3vVg3dn0xdcPSNOGw9zZzB',
#     'id': '3vVg3dn0xdcPSNOGw9zZzB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Black',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/587659653e83b743bca5bc50e0e6872621ef09f9?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3vVg3dn0xdcPSNOGw9zZzB'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rGbkxba8N9yajezrAVMxH'},
#        'href': 'https://api.spotify.com/v1/artists/6rGbkxba8N9yajezrAVMxH',
#        'id': '6rGbkxba8N9yajezrAVMxH',
#        'name': 'Tabata Songs',
#        'type': 'artist',
#        'uri': 'spotify:artist:6rGbkxba8N9yajezrAVMxH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0KCTLM7WmJdBpPQZtlHYQV'},
#      'href': 'https://api.spotify.com/v1/albums/0KCTLM7WmJdBpPQZtlHYQV',
#      'id': '0KCTLM7WmJdBpPQZtlHYQV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f2fb6cdb1596d7c66d82d617',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f2fb6cdb1596d7c66d82d617',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f2fb6cdb1596d7c66d82d617',
#        'width': 64}],
#      'name': 'Back in Black (Tabata)',
#      'release_date': '2020-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0KCTLM7WmJdBpPQZtlHYQV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rGbkxba8N9yajezrAVMxH'},
#       'href': 'https://api.spotify.com/v1/artists/6rGbkxba8N9yajezrAVMxH',
#       'id': '6rGbkxba8N9yajezrAVMxH',
#       'name': 'Tabata Songs',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rGbkxba8N9yajezrAVMxH'}],
#     'disc_number': 1,
#     'duration_ms': 242500,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAEO1942452'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6iuEAXzMXiwylihGE2XmKC'},
#     'href': 'https://api.spotify.com/v1/tracks/6iuEAXzMXiwylihGE2XmKC',
#     'id': '6iuEAXzMXiwylihGE2XmKC',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back in Black (Tabata)',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/588106506108446a53e73603be03192eff375890?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6iuEAXzMXiwylihGE2XmKC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#        'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#        'id': '6urzdpGY5yUimWZsgJUoTb',
#        'name': 'Airbourne',
#        'type': 'artist',
#        'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4HdSbTLqNTWM3FKzrA70O4'},
#      'href': 'https://api.spotify.com/v1/albums/4HdSbTLqNTWM3FKzrA70O4',
#      'id': '4HdSbTLqNTWM3FKzrA70O4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e8f40b4e5cb22ab6d3ac2412',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e8f40b4e5cb22ab6d3ac2412',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e8f40b4e5cb22ab6d3ac2412',
#        'width': 64}],
#      'name': 'Black Dog Barking',
#      'release_date': '2013-05-17',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4HdSbTLqNTWM3FKzrA70O4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6urzdpGY5yUimWZsgJUoTb'},
#       'href': 'https://api.spotify.com/v1/artists/6urzdpGY5yUimWZsgJUoTb',
#       'id': '6urzdpGY5yUimWZsgJUoTb',
#       'name': 'Airbourne',
#       'type': 'artist',
#       'uri': 'spotify:artist:6urzdpGY5yUimWZsgJUoTb'}],
#     'disc_number': 1,
#     'duration_ms': 205506,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA321392615'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/470Fxi4c2a1oJKRNyd5dq4'},
#     'href': 'https://api.spotify.com/v1/tracks/470Fxi4c2a1oJKRNyd5dq4',
#     'id': '470Fxi4c2a1oJKRNyd5dq4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In The Game',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/acae6ca9265acfe87525c510955b43397aa935ee?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:470Fxi4c2a1oJKRNyd5dq4'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6GI52t8N5F02MxU0g5U69P'},
#        'href': 'https://api.spotify.com/v1/artists/6GI52t8N5F02MxU0g5U69P',
#        'id': '6GI52t8N5F02MxU0g5U69P',
#        'name': 'Santana',
#        'type': 'artist',
#        'uri': 'spotify:artist:6GI52t8N5F02MxU0g5U69P'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4YltsTclvvB9OJbSinueLB'},
#      'href': 'https://api.spotify.com/v1/albums/4YltsTclvvB9OJbSinueLB',
#      'id': '4YltsTclvvB9OJbSinueLB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f93cc5905cdd5cb974d4e380',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f93cc5905cdd5cb974d4e380',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f93cc5905cdd5cb974d4e380',
#        'width': 64}],
#      'name': 'Guitar Heaven: The Greatest Guitar Classics Of All Time (Deluxe Version)',
#      'release_date': '2010-09-20',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:4YltsTclvvB9OJbSinueLB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6GI52t8N5F02MxU0g5U69P'},
#       'href': 'https://api.spotify.com/v1/artists/6GI52t8N5F02MxU0g5U69P',
#       'id': '6GI52t8N5F02MxU0g5U69P',
#       'name': 'Santana',
#       'type': 'artist',
#       'uri': 'spotify:artist:6GI52t8N5F02MxU0g5U69P'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/20qISvAhX20dpIbOOzGK3q'},
#       'href': 'https://api.spotify.com/v1/artists/20qISvAhX20dpIbOOzGK3q',
#       'id': '20qISvAhX20dpIbOOzGK3q',
#       'name': 'Nas',
#       'type': 'artist',
#       'uri': 'spotify:artist:20qISvAhX20dpIbOOzGK3q'}],
#     'disc_number': 1,
#     'duration_ms': 260800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAR11000132'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5PHSuk8kUP2BpEF4aSqzPU'},
#     'href': 'https://api.spotify.com/v1/tracks/5PHSuk8kUP2BpEF4aSqzPU',
#     'id': '5PHSuk8kUP2BpEF4aSqzPU',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back In Black (feat. Nas)',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aa205f6d49820cb8ce9b9fac6aa5b5442d934d82?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5PHSuk8kUP2BpEF4aSqzPU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#        'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#        'id': '46SHBwWsqBkxI7EeeBEQG7',
#        'name': 'Kodak Black',
#        'type': 'artist',
#        'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4J5QtgOhv6tPCsxxifVskj'},
#      'href': 'https://api.spotify.com/v1/albums/4J5QtgOhv6tPCsxxifVskj',
#      'id': '4J5QtgOhv6tPCsxxifVskj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325dc1c32dbdd14b8049a3b3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225dc1c32dbdd14b8049a3b3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125dc1c32dbdd14b8049a3b3f',
#        'width': 64}],
#      'name': 'Institution',
#      'release_date': '2015-12-26',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:4J5QtgOhv6tPCsxxifVskj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46SHBwWsqBkxI7EeeBEQG7'},
#       'href': 'https://api.spotify.com/v1/artists/46SHBwWsqBkxI7EeeBEQG7',
#       'id': '46SHBwWsqBkxI7EeeBEQG7',
#       'name': 'Kodak Black',
#       'type': 'artist',
#       'uri': 'spotify:artist:46SHBwWsqBkxI7EeeBEQG7'}],
#     'disc_number': 1,
#     'duration_ms': 183562,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1105699'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7HbJiOw9TePjIcvvHCeWRc'},
#     'href': 'https://api.spotify.com/v1/tracks/7HbJiOw9TePjIcvvHCeWRc',
#     'id': '7HbJiOw9TePjIcvvHCeWRc',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Shake Back',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2869ca40f105ab8aa88701ee5bf48a9556b93966?cid=a3aadf7f4d184af0af9d849d96e89b12',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7HbJiOw9TePjIcvvHCeWRc'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=track%3Aback+in+black+&type=track&market=GB&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 2200}}

# %%
# Get formatted musical data based on track id
spotify.get_musical_data("06AKEBrKUckW0KREUWRnvT")

# %%
spotify.get_tracks(query={"track": "back in black"})
# Out:
# 200
# [{'track_id': '08mG3Y1vljYA6bvDt4Wqkj',
#   'track_name': 'Back In Black',
#   'artist': 'AC/DC',
#   'track_url': 'https://open.spotify.com/track/08mG3Y1vljYA6bvDt4Wqkj',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2730b51f8d91f3a21e8426361ae'},
#  {'track_id': '5S5GRSDNdEPjNjj07gORMf',
#   'track_name': 'Back In The Game',
#   'artist': 'Airbourne',
#   'track_url': 'https://open.spotify.com/track/5S5GRSDNdEPjNjj07gORMf',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2733b99007a3d0b4a5d326843a4'},
#  {'track_id': '2iEGj7kAwH7HAa5epwYwLB',
#   'track_name': 'Back In Black',
#   'artist': 'AC/DC',
#   'track_url': 'https://open.spotify.com/track/2iEGj7kAwH7HAa5epwYwLB',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273b56115c0e231fbf69d3205c6'},
#  {'track_id': '2U2ONBrf1HJCDxQlynpD6J',
#   'track_name': 'Back in Time - featured in "Men In Black 3"',
#   'artist': 'Pitbull',
#   'track_url': 'https://open.spotify.com/track/2U2ONBrf1HJCDxQlynpD6J',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273d879716aef8b4c681ddd0290'},
#  {'track_id': '7JLqofLzcpdjFHc6oRSBGf',
#   'track_name': 'Back In Black - Live at River Plate Stadium, Buenos Aires, Argentina - December 2009',
#   'artist': 'AC/DC',
#   'track_url': 'https://open.spotify.com/track/7JLqofLzcpdjFHc6oRSBGf',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2730a80b890ab011362fd7aa73b'},
#  {'track_id': '5dvfYJR8yXaO9SHtqJWeL5',
#   'track_name': 'Back In Black - Live - 1991',
#   'artist': 'AC/DC',
#   'track_url': 'https://open.spotify.com/track/5dvfYJR8yXaO9SHtqJWeL5',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273c5a5b4be2acc36cddc42fb8f'},
#  {'track_id': '0xh2kZQ3rDB47IS8aVNqrf',
#   'track_name': 'Back in Time - featured in "Men In Black 3"',
#   'artist': 'Pitbull',
#   'track_url': 'https://open.spotify.com/track/0xh2kZQ3rDB47IS8aVNqrf',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b27365045141bb6f165542741ded'},
#  {'track_id': '7fmpKF0rLGPnP7kcQ5ZMm7',
#   'track_name': 'Back in Time - featured in "Men In Black 3"',
#   'artist': 'Pitbull',
#   'track_url': 'https://open.spotify.com/track/7fmpKF0rLGPnP7kcQ5ZMm7',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2732c5b24ecfa39523a75c993c4'},
#  {'track_id': '1MfedNodDKkvTVkNkwIBSo',
#   'track_name': 'Back In Black - Live - 1991',
#   'artist': 'AC/DC',
#   'track_url': 'https://open.spotify.com/track/1MfedNodDKkvTVkNkwIBSo',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b27326b32820b869763b5d706c26'},
#  {'track_id': '6JzkxKjghgLsj14OGz7uKZ',
#   'track_name': 'Back in Black (From "Iron Man 2")',
#   'artist': 'The Neon Crew',
#   'track_url': 'https://open.spotify.com/track/6JzkxKjghgLsj14OGz7uKZ',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273a21619da608f8e276108a8f9'},
#  {'track_id': '4mB7rPwxaQu7WvEHGGulg8',
#   'track_name': 'Back in Black',
#   'artist': 'Robyn Adele Anderson',
#   'track_url': 'https://open.spotify.com/track/4mB7rPwxaQu7WvEHGGulg8',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273d252f84b8b61eaffd44e23c1'},
#  {'track_id': '6z2IGbRAxckusZeMstZ0vH',
#   'track_name': 'Back In Black (Live)',
#   'artist': '2CELLOS',
#   'track_url': 'https://open.spotify.com/track/6z2IGbRAxckusZeMstZ0vH',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b27320ef0f3cdc133b54f9279839'},
#  {'track_id': '06VeVP9K5PIGOwsXV9VBbV',
#   'track_name': 'Back in Black',
#   'artist': 'Tryhardninja',
#   'track_url': 'https://open.spotify.com/track/06VeVP9K5PIGOwsXV9VBbV',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2737aacddc3faa2a680c5d80b58'},
#  {'track_id': '1uAwbHHaDSKJyn90618TB7',
#   'track_name': 'Back To Black - Channel Aid live in Concert 2020 - Live from Elbphilharmonie',
#   'artist': 'Channel Aid',
#   'track_url': 'https://open.spotify.com/track/1uAwbHHaDSKJyn90618TB7',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273ed288b0c9efcc0c9455a898d'},
#  {'track_id': '6gS95ZPBPe5W04ATRlJNuI',
#   'track_name': 'Back in Black',
#   'artist': 'Sershen&Zaritskaya',
#   'track_url': 'https://open.spotify.com/track/6gS95ZPBPe5W04ATRlJNuI',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2732755d6e4e725a4dc53f7ba5f'},
#  {'track_id': '3vVg3dn0xdcPSNOGw9zZzB',
#   'track_name': 'Back in Black',
#   'artist': 'Tiger Stripes',
#   'track_url': 'https://open.spotify.com/track/3vVg3dn0xdcPSNOGw9zZzB',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b2732c9cb8604700381eb8f88543'},
#  {'track_id': '6iuEAXzMXiwylihGE2XmKC',
#   'track_name': 'Back in Black (Tabata)',
#   'artist': 'Tabata Songs',
#   'track_url': 'https://open.spotify.com/track/6iuEAXzMXiwylihGE2XmKC',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273f2fb6cdb1596d7c66d82d617'},
#  {'track_id': '470Fxi4c2a1oJKRNyd5dq4',
#   'track_name': 'Back In The Game',
#   'artist': 'Airbourne',
#   'track_url': 'https://open.spotify.com/track/470Fxi4c2a1oJKRNyd5dq4',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273e8f40b4e5cb22ab6d3ac2412'},
#  {'track_id': '5PHSuk8kUP2BpEF4aSqzPU',
#   'track_name': 'Back In Black (feat. Nas)',
#   'artist': 'Santana',
#   'track_url': 'https://open.spotify.com/track/5PHSuk8kUP2BpEF4aSqzPU',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b273f93cc5905cdd5cb974d4e380'},
#  {'track_id': '7HbJiOw9TePjIcvvHCeWRc',
#   'track_name': 'Shake Back',
#   'artist': 'Kodak Black',
#   'track_url': 'https://open.spotify.com/track/7HbJiOw9TePjIcvvHCeWRc',
#   'image_url': 'https://i.scdn.co/image/ab67616d0000b27325dc1c32dbdd14b8049a3b3f'}]

# %%
spotify.get_resource("6pgdQaFfwbEXeaKAnuvXNM")
# Out:
# {}

# %%
from pprint import pprint
pprint(artist)
# Out:
# {}

# %%
artist['id']
# Out:
# '711MCceyCBcFnzjGY4Q7Un'
